# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# Import the datetime module from the datetime library.
from datetime import datetime
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy
# Import the requests library.
import requests
# Import the API key.
from config import weather_api_key

# %%
# Create a new set of 2,000 random latitudes and longitudes.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lats_lngs = zip(lats,lngs)
lats_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lats_lngs)

# %%
# Nearest citie susing the citipy module
# List for holding cities
cities = []
# iterate through coordinates
for coord in coordinates:
    city = citipy.nearest_city(coord[0], coord[1]).city_name
    if city not in cities:
        cities.append(city)
# Length of the cities found
print(len(cities))
# Out:
# 767

# %%
# API call in the OpenWeatherMap
# Starting URL for Weather Map API Call.
url = f"http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid={weather_api_key}"

# %%
# Retrieving: Latitude and longitude, Maximum temperature, Percent humidity, Percent cloudiness, Wind speed, Weather description
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_country = city_weather["sys"]["country"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | amahai
# Processing Record 2 of Set 1 | gubkinskiy
# Processing Record 3 of Set 1 | burica
# City not found. Skipping...
# Processing Record 4 of Set 1 | salisbury
# Processing Record 5 of Set 1 | punta arenas
# Processing Record 6 of Set 1 | fortuna
# Processing Record 7 of Set 1 | rikitea
# Processing Record 8 of Set 1 | chokurdakh
# Processing Record 9 of Set 1 | new norfolk
# Processing Record 10 of Set 1 | tasiilaq
# Processing Record 11 of Set 1 | sao jose de piranhas
# Processing Record 12 of Set 1 | la ronge
# Processing Record 13 of Set 1 | albany
# Processing Record 14 of Set 1 | raudeberg
# Processing Record 15 of Set 1 | tiksi
# Processing Record 16 of Set 1 | ushuaia
# Processing Record 17 of Set 1 | dom pedrito
# Processing Record 18 of Set 1 | hobart
# Processing Record 19 of Set 1 | hilo
# Processing Record 20 of Set 1 | dire dawa
# Processing Record 21 of Set 1 | ayolas
# Processing Record 22 of Set 1 | busselton
# Processing Record 23 of Set 1 | hailar
# Processing Record 24 of Set 1 | vaini
# Processing Record 25 of Set 1 | mahibadhoo
# Processing Record 26 of Set 1 | bethel
# Processing Record 27 of Set 1 | addanki
# Processing Record 28 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 29 of Set 1 | husavik
# Processing Record 30 of Set 1 | college
# Processing Record 31 of Set 1 | deputatskiy
# Processing Record 32 of Set 1 | hubli
# Processing Record 33 of Set 1 | vila velha
# Processing Record 34 of Set 1 | freeport
# Processing Record 35 of Set 1 | bani
# Processing Record 36 of Set 1 | saint-philippe
# Processing Record 37 of Set 1 | komsomolskiy
# Processing Record 38 of Set 1 | haines junction
# Processing Record 39 of Set 1 | cockburn town
# Processing Record 40 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 41 of Set 1 | ballina
# Processing Record 42 of Set 1 | aksu
# Processing Record 43 of Set 1 | bluff
# Processing Record 44 of Set 1 | pevek
# Processing Record 45 of Set 1 | narsaq
# Processing Record 46 of Set 1 | kaitangata
# Processing Record 47 of Set 1 | ust-tsilma
# Processing Record 48 of Set 1 | mataura
# Processing Record 49 of Set 1 | quatre cocos
# Processing Record 50 of Set 1 | cidreira
# Processing Record 1 of Set 2 | salalah
# Processing Record 2 of Set 2 | makakilo city
# Processing Record 3 of Set 2 | te anau
# Processing Record 4 of Set 2 | san miguel
# Processing Record 5 of Set 2 | vila franca do campo
# Processing Record 6 of Set 2 | shirokiy
# Processing Record 7 of Set 2 | kapaa
# Processing Record 8 of Set 2 | esperance
# Processing Record 9 of Set 2 | gombong
# Processing Record 10 of Set 2 | noumea
# Processing Record 11 of Set 2 | dingle
# Processing Record 12 of Set 2 | maceio
# Processing Record 13 of Set 2 | tuktoyaktuk
# Processing Record 14 of Set 2 | walvis bay
# Processing Record 15 of Set 2 | nanortalik
# Processing Record 16 of Set 2 | udachnyy
# Processing Record 17 of Set 2 | puerto leguizamo
# Processing Record 18 of Set 2 | lorengau
# Processing Record 19 of Set 2 | cape town
# Processing Record 20 of Set 2 | la reforma
# Processing Record 21 of Set 2 | provideniya
# Processing Record 22 of Set 2 | puerto ayora
# Processing Record 23 of Set 2 | cumaribo
# City not found. Skipping...
# Processing Record 24 of Set 2 | iralaya
# Processing Record 25 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 26 of Set 2 | nome
# Processing Record 27 of Set 2 | port elizabeth
# Processing Record 28 of Set 2 | hualmay
# Processing Record 29 of Set 2 | hermanus
# Processing Record 30 of Set 2 | azangaro
# Processing Record 31 of Set 2 | cabo san lucas
# Processing Record 32 of Set 2 | oranjemund
# Processing Record 33 of Set 2 | auki
# Processing Record 34 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 35 of Set 2 | namatanai
# Processing Record 36 of Set 2 | barrow
# Processing Record 37 of Set 2 | camopi
# Processing Record 38 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 39 of Set 2 | katobu
# Processing Record 40 of Set 2 | mahadday weyne
# City not found. Skipping...
# Processing Record 41 of Set 2 | lebu
# Processing Record 42 of Set 2 | kavieng
# Processing Record 43 of Set 2 | ahipara
# Processing Record 44 of Set 2 | lodja
# Processing Record 45 of Set 2 | cherskiy
# Processing Record 46 of Set 2 | coquimbo
# Processing Record 47 of Set 2 | daru
# Processing Record 48 of Set 2 | kalomo
# City not found. Skipping...
# Processing Record 49 of Set 2 | petropavlovka
# Processing Record 50 of Set 2 | careiro da varzea
# Processing Record 1 of Set 3 | khatanga
# Processing Record 2 of Set 3 | guerrero negro
# Processing Record 3 of Set 3 | mahebourg
# Processing Record 4 of Set 3 | meulaboh
# Processing Record 5 of Set 3 | xingcheng
# Processing Record 6 of Set 3 | tigil
# Processing Record 7 of Set 3 | kodiak
# Processing Record 8 of Set 3 | qaanaaq
# Processing Record 9 of Set 3 | ciudad real
# Processing Record 10 of Set 3 | sur
# Processing Record 11 of Set 3 | puri
# Processing Record 12 of Set 3 | berlevag
# Processing Record 13 of Set 3 | sioux city
# Processing Record 14 of Set 3 | meyungs
# City not found. Skipping...
# Processing Record 15 of Set 3 | fairbanks
# Processing Record 16 of Set 3 | malkangiri
# Processing Record 17 of Set 3 | victoria
# Processing Record 18 of Set 3 | dinan
# Processing Record 19 of Set 3 | kruisfontein
# Processing Record 20 of Set 3 | labuhan
# Processing Record 21 of Set 3 | east london
# Processing Record 22 of Set 3 | tungkang
# City not found. Skipping...
# Processing Record 23 of Set 3 | rawson
# Processing Record 24 of Set 3 | iqaluit
# Processing Record 25 of Set 3 | upernavik
# Processing Record 26 of Set 3 | pucara
# Processing Record 27 of Set 3 | port alfred
# Processing Record 28 of Set 3 | mar del plata
# Processing Record 29 of Set 3 | chuy
# Processing Record 30 of Set 3 | ribeira grande
# Processing Record 31 of Set 3 | saint-leu
# Processing Record 32 of Set 3 | butaritari
# Processing Record 33 of Set 3 | jamestown
# Processing Record 34 of Set 3 | adrar
# Processing Record 35 of Set 3 | north las vegas
# Processing Record 36 of Set 3 | port hueneme
# Processing Record 37 of Set 3 | novovorontsovka
# Processing Record 38 of Set 3 | utete
# Processing Record 39 of Set 3 | tabiauea
# City not found. Skipping...
# Processing Record 40 of Set 3 | saldanha
# Processing Record 41 of Set 3 | okahandja
# Processing Record 42 of Set 3 | jinxiang
# Processing Record 43 of Set 3 | jomalig
# City not found. Skipping...
# Processing Record 44 of Set 3 | nancha
# Processing Record 45 of Set 3 | yulara
# Processing Record 46 of Set 3 | sabla
# Processing Record 47 of Set 3 | bredasdorp
# Processing Record 48 of Set 3 | osa
# Processing Record 49 of Set 3 | vanavara
# Processing Record 50 of Set 3 | salym
# Processing Record 1 of Set 4 | karasjok
# Processing Record 2 of Set 4 | waingapu
# Processing Record 3 of Set 4 | kindu
# Processing Record 4 of Set 4 | vrangel
# Processing Record 5 of Set 4 | winona
# Processing Record 6 of Set 4 | hanmer springs
# Processing Record 7 of Set 4 | longyearbyen
# Processing Record 8 of Set 4 | jiazi
# Processing Record 9 of Set 4 | souillac
# Processing Record 10 of Set 4 | rudbar
# Processing Record 11 of Set 4 | cam ranh
# Processing Record 12 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 13 of Set 4 | kokopo
# Processing Record 14 of Set 4 | porangatu
# Processing Record 15 of Set 4 | luganville
# Processing Record 16 of Set 4 | coxim
# Processing Record 17 of Set 4 | castro
# Processing Record 18 of Set 4 | georgetown
# Processing Record 19 of Set 4 | ponta do sol
# Processing Record 20 of Set 4 | lagoa
# Processing Record 21 of Set 4 | caucaia
# Processing Record 22 of Set 4 | yellowknife
# Processing Record 23 of Set 4 | leningradskiy
# Processing Record 24 of Set 4 | kolondieba
# Processing Record 25 of Set 4 | thompson
# Processing Record 26 of Set 4 | galle
# Processing Record 27 of Set 4 | jinchang
# Processing Record 28 of Set 4 | tubuala
# Processing Record 29 of Set 4 | karwar
# Processing Record 30 of Set 4 | peniche
# Processing Record 31 of Set 4 | marsa matruh
# Processing Record 32 of Set 4 | shache
# Processing Record 33 of Set 4 | ilulissat
# Processing Record 34 of Set 4 | lichuan
# Processing Record 35 of Set 4 | barra dos coqueiros
# Processing Record 36 of Set 4 | vestmanna
# Processing Record 37 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 38 of Set 4 | the pas
# Processing Record 39 of Set 4 | elko
# Processing Record 40 of Set 4 | vardo
# Processing Record 41 of Set 4 | kutum
# Processing Record 42 of Set 4 | gat
# Processing Record 43 of Set 4 | broken hill
# Processing Record 44 of Set 4 | itarema
# Processing Record 45 of Set 4 | lasa
# Processing Record 46 of Set 4 | kaeo
# Processing Record 47 of Set 4 | manzil jamil
# City not found. Skipping...
# Processing Record 48 of Set 4 | tahe
# Processing Record 49 of Set 4 | namibe
# Processing Record 50 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 1 of Set 5 | koumac
# Processing Record 2 of Set 5 | havre-saint-pierre
# Processing Record 3 of Set 5 | shizunai
# Processing Record 4 of Set 5 | kombissiri
# Processing Record 5 of Set 5 | hyderabad
# Processing Record 6 of Set 5 | denpasar
# Processing Record 7 of Set 5 | hofn
# Processing Record 8 of Set 5 | pacific grove
# Processing Record 9 of Set 5 | naze
# Processing Record 10 of Set 5 | talnakh
# Processing Record 11 of Set 5 | rathdrum
# Processing Record 12 of Set 5 | touros
# Processing Record 13 of Set 5 | santa fe
# Processing Record 14 of Set 5 | praia
# Processing Record 15 of Set 5 | dikson
# Processing Record 16 of Set 5 | trinidad
# Processing Record 17 of Set 5 | tiznit
# Processing Record 18 of Set 5 | bardiyah
# Processing Record 19 of Set 5 | bilibino
# Processing Record 20 of Set 5 | thano bula khan
# City not found. Skipping...
# Processing Record 21 of Set 5 | yabassi
# Processing Record 22 of Set 5 | brae
# Processing Record 23 of Set 5 | alofi
# Processing Record 24 of Set 5 | katangli
# Processing Record 25 of Set 5 | oktyabrskiy
# Processing Record 26 of Set 5 | rio gallegos
# Processing Record 27 of Set 5 | tocopilla
# Processing Record 28 of Set 5 | khani
# Processing Record 29 of Set 5 | severo-kurilsk
# Processing Record 30 of Set 5 | isla mujeres
# Processing Record 31 of Set 5 | coahuayana
# Processing Record 32 of Set 5 | ibanda
# Processing Record 33 of Set 5 | shasta lake
# Processing Record 34 of Set 5 | tilichiki
# Processing Record 35 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 36 of Set 5 | jieshi
# Processing Record 37 of Set 5 | vestmannaeyjar
# Processing Record 38 of Set 5 | baoshan
# Processing Record 39 of Set 5 | inta
# Processing Record 40 of Set 5 | nikolskoye
# Processing Record 41 of Set 5 | suluq
# Processing Record 42 of Set 5 | darnah
# Processing Record 43 of Set 5 | arraial do cabo
# Processing Record 44 of Set 5 | mendi
# Processing Record 45 of Set 5 | atuona
# Processing Record 46 of Set 5 | samalaeulu
# City not found. Skipping...
# Processing Record 47 of Set 5 | afrikanda
# Processing Record 48 of Set 5 | shar
# Processing Record 49 of Set 5 | lompoc
# Processing Record 50 of Set 5 | okha
# Processing Record 1 of Set 6 | vazante
# Processing Record 2 of Set 6 | biak
# Processing Record 3 of Set 6 | plettenberg bay
# Processing Record 4 of Set 6 | vao
# Processing Record 5 of Set 6 | mandiana
# Processing Record 6 of Set 6 | presidente medici
# Processing Record 7 of Set 6 | shurugwi
# Processing Record 8 of Set 6 | hornepayne
# Processing Record 9 of Set 6 | bengkulu
# Processing Record 10 of Set 6 | sabang
# Processing Record 11 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 12 of Set 6 | obsharovka
# Processing Record 13 of Set 6 | inirida
# Processing Record 14 of Set 6 | svetlogorsk
# Processing Record 15 of Set 6 | la ciotat
# Processing Record 16 of Set 6 | carnarvon
# Processing Record 17 of Set 6 | saint george
# Processing Record 18 of Set 6 | port-gentil
# Processing Record 19 of Set 6 | sivas
# Processing Record 20 of Set 6 | palmer
# Processing Record 21 of Set 6 | lolua
# City not found. Skipping...
# Processing Record 22 of Set 6 | christchurch
# Processing Record 23 of Set 6 | najran
# Processing Record 24 of Set 6 | pisco
# Processing Record 25 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 26 of Set 6 | lata
# Processing Record 27 of Set 6 | kangaatsiaq
# Processing Record 28 of Set 6 | lavrentiya
# Processing Record 29 of Set 6 | oistins
# Processing Record 30 of Set 6 | ewa beach
# Processing Record 31 of Set 6 | avarua
# Processing Record 32 of Set 6 | falealupo
# City not found. Skipping...
# Processing Record 33 of Set 6 | oranjestad
# Processing Record 34 of Set 6 | kormilovka
# Processing Record 35 of Set 6 | sayat
# Processing Record 36 of Set 6 | hamilton
# Processing Record 37 of Set 6 | kantang
# Processing Record 38 of Set 6 | solnechnyy
# Processing Record 39 of Set 6 | shu
# Processing Record 40 of Set 6 | nizhniy kuranakh
# Processing Record 41 of Set 6 | juneau
# Processing Record 42 of Set 6 | almaty
# Processing Record 43 of Set 6 | maghama
# City not found. Skipping...
# Processing Record 44 of Set 6 | bodden town
# Processing Record 45 of Set 6 | nantucket
# Processing Record 46 of Set 6 | airai
# Processing Record 47 of Set 6 | torbay
# Processing Record 48 of Set 6 | lamar
# Processing Record 49 of Set 6 | aksarka
# Processing Record 50 of Set 6 | nuuk
# Processing Record 1 of Set 7 | faanui
# Processing Record 2 of Set 7 | piopio
# Processing Record 3 of Set 7 | ancud
# Processing Record 4 of Set 7 | chabahar
# Processing Record 5 of Set 7 | sinnamary
# Processing Record 6 of Set 7 | mahajanga
# Processing Record 7 of Set 7 | samarai
# Processing Record 8 of Set 7 | flinders
# Processing Record 9 of Set 7 | karkaralinsk
# City not found. Skipping...
# Processing Record 10 of Set 7 | boende
# Processing Record 11 of Set 7 | atambua
# Processing Record 12 of Set 7 | umzimvubu
# City not found. Skipping...
# Processing Record 13 of Set 7 | santona
# Processing Record 14 of Set 7 | verkhnyaya inta
# Processing Record 15 of Set 7 | durban
# Processing Record 16 of Set 7 | yarim
# Processing Record 17 of Set 7 | saint anthony
# Processing Record 18 of Set 7 | havelock
# Processing Record 19 of Set 7 | lahij
# Processing Record 20 of Set 7 | honiara
# Processing Record 21 of Set 7 | mayna
# Processing Record 22 of Set 7 | barentsburg
# City not found. Skipping...
# Processing Record 23 of Set 7 | natal
# Processing Record 24 of Set 7 | zhanaozen
# Processing Record 25 of Set 7 | zalegoshch
# Processing Record 26 of Set 7 | kirakira
# Processing Record 27 of Set 7 | inuvik
# Processing Record 28 of Set 7 | urdzhar
# City not found. Skipping...
# Processing Record 29 of Set 7 | evensk
# Processing Record 30 of Set 7 | roald
# Processing Record 31 of Set 7 | mount gambier
# Processing Record 32 of Set 7 | omboue
# Processing Record 33 of Set 7 | monteiro
# Processing Record 34 of Set 7 | largo
# Processing Record 35 of Set 7 | xochitlan
# Processing Record 36 of Set 7 | utiroa
# City not found. Skipping...
# Processing Record 37 of Set 7 | san patricio
# Processing Record 38 of Set 7 | saint-georges
# Processing Record 39 of Set 7 | humberto de campos
# Processing Record 40 of Set 7 | fukue
# Processing Record 41 of Set 7 | gizo
# Processing Record 42 of Set 7 | bac lieu
# Processing Record 43 of Set 7 | hastings
# Processing Record 44 of Set 7 | impfondo
# Processing Record 45 of Set 7 | sakakah
# Processing Record 46 of Set 7 | taganak
# Processing Record 47 of Set 7 | lima
# Processing Record 48 of Set 7 | narsimhapur
# Processing Record 49 of Set 7 | ca mau
# Processing Record 50 of Set 7 | nabire
# Processing Record 1 of Set 8 | argelia
# Processing Record 2 of Set 8 | jumla
# Processing Record 3 of Set 8 | hithadhoo
# Processing Record 4 of Set 8 | necochea
# Processing Record 5 of Set 8 | srednekolymsk
# Processing Record 6 of Set 8 | port hedland
# Processing Record 7 of Set 8 | suntar
# Processing Record 8 of Set 8 | hami
# Processing Record 9 of Set 8 | waipawa
# Processing Record 10 of Set 8 | luebo
# Processing Record 11 of Set 8 | kerema
# Processing Record 12 of Set 8 | kharitonovo
# Processing Record 13 of Set 8 | santiago
# Processing Record 14 of Set 8 | san juan
# Processing Record 15 of Set 8 | khandyga
# Processing Record 16 of Set 8 | puerto suarez
# Processing Record 17 of Set 8 | baruun-urt
# Processing Record 18 of Set 8 | mama
# Processing Record 19 of Set 8 | sibanicu
# Processing Record 20 of Set 8 | kavaratti
# Processing Record 21 of Set 8 | disna
# Processing Record 22 of Set 8 | loa janan
# Processing Record 23 of Set 8 | yerbogachen
# Processing Record 24 of Set 8 | sambava
# Processing Record 25 of Set 8 | puerto berrio
# Processing Record 26 of Set 8 | radovanu
# Processing Record 27 of Set 8 | bajo baudo
# City not found. Skipping...
# Processing Record 28 of Set 8 | jalu
# Processing Record 29 of Set 8 | padang
# Processing Record 30 of Set 8 | venezuela
# Processing Record 31 of Set 8 | tucuman
# Processing Record 32 of Set 8 | douglas
# Processing Record 33 of Set 8 | cabedelo
# Processing Record 34 of Set 8 | grand gaube
# Processing Record 35 of Set 8 | turbat
# Processing Record 36 of Set 8 | mackay
# Processing Record 37 of Set 8 | faya
# Processing Record 38 of Set 8 | ayorou
# Processing Record 39 of Set 8 | hohhot
# Processing Record 40 of Set 8 | ijaki
# City not found. Skipping...
# Processing Record 41 of Set 8 | maloshuyka
# City not found. Skipping...
# Processing Record 42 of Set 8 | scottsbluff
# Processing Record 43 of Set 8 | blackwater
# Processing Record 44 of Set 8 | cravo norte
# Processing Record 45 of Set 8 | abrau-dyurso
# Processing Record 46 of Set 8 | elat
# Processing Record 47 of Set 8 | maiduguri
# Processing Record 48 of Set 8 | salvador
# Processing Record 49 of Set 8 | aklavik
# Processing Record 50 of Set 8 | bardsir
# Processing Record 1 of Set 9 | kadykchan
# City not found. Skipping...
# Processing Record 2 of Set 9 | krasnyy chikoy
# Processing Record 3 of Set 9 | attawapiskat
# City not found. Skipping...
# Processing Record 4 of Set 9 | egvekinot
# Processing Record 5 of Set 9 | concordia
# Processing Record 6 of Set 9 | clyde river
# Processing Record 7 of Set 9 | grand river south east
# City not found. Skipping...
# Processing Record 8 of Set 9 | shenjiamen
# Processing Record 9 of Set 9 | mendoza
# Processing Record 10 of Set 9 | xai-xai
# Processing Record 11 of Set 9 | mala
# Processing Record 12 of Set 9 | valdivia
# Processing Record 13 of Set 9 | rancho palos verdes
# Processing Record 14 of Set 9 | crotone
# Processing Record 15 of Set 9 | sola
# Processing Record 16 of Set 9 | katsuura
# Processing Record 17 of Set 9 | cairns
# Processing Record 18 of Set 9 | tuatapere
# Processing Record 19 of Set 9 | daitari
# Processing Record 20 of Set 9 | harrison
# Processing Record 21 of Set 9 | heihe
# Processing Record 22 of Set 9 | aldan
# Processing Record 23 of Set 9 | shelburne
# Processing Record 24 of Set 9 | temaraia
# City not found. Skipping...
# Processing Record 25 of Set 9 | warqla
# City not found. Skipping...
# Processing Record 26 of Set 9 | dwarka
# Processing Record 27 of Set 9 | norman wells
# Processing Record 28 of Set 9 | atkinson
# Processing Record 29 of Set 9 | itea
# Processing Record 30 of Set 9 | caravelas
# Processing Record 31 of Set 9 | casas grandes
# Processing Record 32 of Set 9 | tautira
# Processing Record 33 of Set 9 | kedarnath
# City not found. Skipping...
# Processing Record 34 of Set 9 | porto novo
# Processing Record 35 of Set 9 | ust-kulom
# Processing Record 36 of Set 9 | vostok
# Processing Record 37 of Set 9 | wilkie
# Processing Record 38 of Set 9 | americana
# Processing Record 39 of Set 9 | porgera
# Processing Record 40 of Set 9 | tual
# Processing Record 41 of Set 9 | sinkat
# City not found. Skipping...
# Processing Record 42 of Set 9 | aguimes
# Processing Record 43 of Set 9 | elk city
# Processing Record 44 of Set 9 | madang
# Processing Record 45 of Set 9 | mehamn
# Processing Record 46 of Set 9 | mullaitivu
# City not found. Skipping...
# Processing Record 47 of Set 9 | hoopstad
# Processing Record 48 of Set 9 | ambilobe
# Processing Record 49 of Set 9 | uyuni
# Processing Record 50 of Set 9 | hirara
# Processing Record 1 of Set 10 | gavle
# Processing Record 2 of Set 10 | los llanos de aridane
# Processing Record 3 of Set 10 | shitanjing
# Processing Record 4 of Set 10 | ahvaz
# Processing Record 5 of Set 10 | bambous virieux
# Processing Record 6 of Set 10 | barbar
# City not found. Skipping...
# Processing Record 7 of Set 10 | buchanan
# Processing Record 8 of Set 10 | iskilip
# Processing Record 9 of Set 10 | bihariganj
# Processing Record 10 of Set 10 | altay
# Processing Record 11 of Set 10 | pavlovka
# Processing Record 12 of Set 10 | rondonopolis
# Processing Record 13 of Set 10 | capinzal
# Processing Record 14 of Set 10 | tura
# Processing Record 15 of Set 10 | hervey bay
# Processing Record 16 of Set 10 | pimentel
# Processing Record 17 of Set 10 | aleksandrov gay
# Processing Record 18 of Set 10 | comodoro rivadavia
# Processing Record 19 of Set 10 | sitka
# Processing Record 20 of Set 10 | saskylakh
# Processing Record 21 of Set 10 | sorland
# Processing Record 22 of Set 10 | tazovskiy
# Processing Record 23 of Set 10 | jablah
# Processing Record 24 of Set 10 | contai
# Processing Record 25 of Set 10 | sydney
# Processing Record 26 of Set 10 | ust-nera
# Processing Record 27 of Set 10 | banda aceh
# Processing Record 28 of Set 10 | sibolga
# Processing Record 29 of Set 10 | upata
# Processing Record 30 of Set 10 | avera
# Processing Record 31 of Set 10 | kamaishi
# Processing Record 32 of Set 10 | sonoita
# Processing Record 33 of Set 10 | andenes
# Processing Record 34 of Set 10 | tabulbah
# City not found. Skipping...
# Processing Record 35 of Set 10 | kawhia
# Processing Record 36 of Set 10 | litovko
# Processing Record 37 of Set 10 | luderitz
# Processing Record 38 of Set 10 | shingu
# Processing Record 39 of Set 10 | marystown
# Processing Record 40 of Set 10 | kundiawa
# Processing Record 41 of Set 10 | chara
# Processing Record 42 of Set 10 | neiafu
# Processing Record 43 of Set 10 | tubmanburg
# Processing Record 44 of Set 10 | shuiji
# Processing Record 45 of Set 10 | santa cruz
# Processing Record 46 of Set 10 | sungairaya
# Processing Record 47 of Set 10 | grindavik
# Processing Record 48 of Set 10 | duvan
# Processing Record 49 of Set 10 | dunedin
# Processing Record 50 of Set 10 | kaka
# Processing Record 1 of Set 11 | ternuvate
# Processing Record 2 of Set 11 | margate
# Processing Record 3 of Set 11 | laje
# Processing Record 4 of Set 11 | yangambi
# Processing Record 5 of Set 11 | hovd
# Processing Record 6 of Set 11 | klaksvik
# Processing Record 7 of Set 11 | coihaique
# Processing Record 8 of Set 11 | kulhudhuffushi
# Processing Record 9 of Set 11 | calbuco
# Processing Record 10 of Set 11 | juegang
# Processing Record 11 of Set 11 | puerto escondido
# Processing Record 12 of Set 11 | cayenne
# Processing Record 13 of Set 11 | formosa do rio preto
# Processing Record 14 of Set 11 | tarakan
# Processing Record 15 of Set 11 | kayes
# Processing Record 16 of Set 11 | hobyo
# Processing Record 17 of Set 11 | bandarbeyla
# Processing Record 18 of Set 11 | vidim
# Processing Record 19 of Set 11 | mondlo
# Processing Record 20 of Set 11 | bras-panon
# Processing Record 21 of Set 11 | rincon
# Processing Record 22 of Set 11 | riohacha
# Processing Record 23 of Set 11 | kuznechnoye
# Processing Record 24 of Set 11 | buritis
# Processing Record 25 of Set 11 | genhe
# Processing Record 26 of Set 11 | erzin
# Processing Record 27 of Set 11 | skibbereen
# Processing Record 28 of Set 11 | gawler
# Processing Record 29 of Set 11 | batemans bay
# Processing Record 30 of Set 11 | novikovo
# Processing Record 31 of Set 11 | kosh-agach
# Processing Record 32 of Set 11 | tulsipur
# Processing Record 33 of Set 11 | kahului
# Processing Record 34 of Set 11 | yarmouth
# Processing Record 35 of Set 11 | camacha
# Processing Record 36 of Set 11 | mount isa
# Processing Record 37 of Set 11 | khor
# Processing Record 38 of Set 11 | krasnorechenskiy
# Processing Record 39 of Set 11 | rio claro
# Processing Record 40 of Set 11 | samsun
# Processing Record 41 of Set 11 | kayerkan
# Processing Record 42 of Set 11 | boddam
# Processing Record 43 of Set 11 | havoysund
# Processing Record 44 of Set 11 | abu dhabi
# Processing Record 45 of Set 11 | alihe
# Processing Record 46 of Set 11 | matay
# Processing Record 47 of Set 11 | liverpool
# Processing Record 48 of Set 11 | krasnoarmeyskoye
# Processing Record 49 of Set 11 | xinmin
# Processing Record 50 of Set 11 | nalut
# Processing Record 1 of Set 12 | malakal
# Processing Record 2 of Set 12 | rio grande
# Processing Record 3 of Set 12 | nouadhibou
# Processing Record 4 of Set 12 | bathsheba
# Processing Record 5 of Set 12 | raymond
# Processing Record 6 of Set 12 | eureka
# Processing Record 7 of Set 12 | inderborskiy
# City not found. Skipping...
# Processing Record 8 of Set 12 | blytheville
# Processing Record 9 of Set 12 | sao miguel do araguaia
# Processing Record 10 of Set 12 | det udom
# Processing Record 11 of Set 12 | osakarovka
# Processing Record 12 of Set 12 | afantou
# Processing Record 13 of Set 12 | boyolangu
# Processing Record 14 of Set 12 | formoso do araguaia
# City not found. Skipping...
# Processing Record 15 of Set 12 | andra
# Processing Record 16 of Set 12 | battle creek
# Processing Record 17 of Set 12 | vila do maio
# Processing Record 18 of Set 12 | lashio
# Processing Record 19 of Set 12 | road town
# Processing Record 20 of Set 12 | kegums
# Processing Record 21 of Set 12 | lufilufi
# Processing Record 22 of Set 12 | matara
# Processing Record 23 of Set 12 | dolzhanskaya
# Processing Record 24 of Set 12 | tanda
# Processing Record 25 of Set 12 | voh
# Processing Record 26 of Set 12 | portales
# Processing Record 27 of Set 12 | trairi
# Processing Record 28 of Set 12 | velika gorica
# Processing Record 29 of Set 12 | moses lake
# Processing Record 30 of Set 12 | pullman
# Processing Record 31 of Set 12 | sao filipe
# Processing Record 32 of Set 12 | jiuquan
# Processing Record 33 of Set 12 | taunggyi
# Processing Record 34 of Set 12 | roswell
# Processing Record 35 of Set 12 | san cristobal
# Processing Record 36 of Set 12 | uren
# Processing Record 37 of Set 12 | libenge
# Processing Record 38 of Set 12 | tahta
# Processing Record 39 of Set 12 | dagua
# Processing Record 40 of Set 12 | yashan
# Processing Record 41 of Set 12 | huanan
# Processing Record 42 of Set 12 | raymondville
# Processing Record 43 of Set 12 | vila
# Processing Record 44 of Set 12 | andilamena
# Processing Record 45 of Set 12 | pokhara
# Processing Record 46 of Set 12 | nguiu
# City not found. Skipping...
# Processing Record 47 of Set 12 | atherton
# Processing Record 48 of Set 12 | carmen
# Processing Record 49 of Set 12 | sibu
# Processing Record 50 of Set 12 | silyanah
# City not found. Skipping...
# Processing Record 1 of Set 13 | chiang kham
# Processing Record 2 of Set 13 | traverse city
# Processing Record 3 of Set 13 | adre
# Processing Record 4 of Set 13 | gallup
# Processing Record 5 of Set 13 | shostka
# Processing Record 6 of Set 13 | igrim
# Processing Record 7 of Set 13 | tvoroyri
# Processing Record 8 of Set 13 | mount darwin
# Processing Record 9 of Set 13 | mancio lima
# Processing Record 10 of Set 13 | bulgan
# Processing Record 11 of Set 13 | sosva
# Processing Record 12 of Set 13 | dembi dolo
# Processing Record 13 of Set 13 | kamenskoye
# City not found. Skipping...
# Processing Record 14 of Set 13 | varhaug
# Processing Record 15 of Set 13 | dir
# Processing Record 16 of Set 13 | angoram
# Processing Record 17 of Set 13 | kalengwa
# Processing Record 18 of Set 13 | scotts valley
# Processing Record 19 of Set 13 | catuday
# Processing Record 20 of Set 13 | half moon bay
# Processing Record 21 of Set 13 | perth
# Processing Record 22 of Set 13 | karaul
# City not found. Skipping...
# Processing Record 23 of Set 13 | skibotn
# Processing Record 24 of Set 13 | abonnema
# Processing Record 25 of Set 13 | damghan
# Processing Record 26 of Set 13 | illapel
# Processing Record 27 of Set 13 | loiza
# Processing Record 28 of Set 13 | catina
# Processing Record 29 of Set 13 | bafra
# Processing Record 30 of Set 13 | ikom
# Processing Record 31 of Set 13 | korsor
# Processing Record 32 of Set 13 | shimoda
# Processing Record 33 of Set 13 | svobodnyy
# Processing Record 34 of Set 13 | iracoubo
# Processing Record 35 of Set 13 | tres arroyos
# Processing Record 36 of Set 13 | san quintin
# Processing Record 37 of Set 13 | borodino
# Processing Record 38 of Set 13 | bernau
# Processing Record 39 of Set 13 | lyuban
# Processing Record 40 of Set 13 | miraflores
# Processing Record 41 of Set 13 | cavalcante
# Processing Record 42 of Set 13 | karasburg
# Processing Record 43 of Set 13 | tarudant
# City not found. Skipping...
# Processing Record 44 of Set 13 | naliya
# Processing Record 45 of Set 13 | fort morgan
# Processing Record 46 of Set 13 | sao gabriel da cachoeira
# Processing Record 47 of Set 13 | gezing
# Processing Record 48 of Set 13 | minot
# Processing Record 49 of Set 13 | verkhoyansk
# Processing Record 50 of Set 13 | villazon
# Processing Record 1 of Set 14 | hasaki
# Processing Record 2 of Set 14 | nishihara
# Processing Record 3 of Set 14 | antsohihy
# Processing Record 4 of Set 14 | tala
# Processing Record 5 of Set 14 | laguna
# Processing Record 6 of Set 14 | touba
# Processing Record 7 of Set 14 | labutta
# City not found. Skipping...
# Processing Record 8 of Set 14 | chibuto
# Processing Record 9 of Set 14 | la rioja
# Processing Record 10 of Set 14 | villa bruzual
# Processing Record 11 of Set 14 | chengde
# Processing Record 12 of Set 14 | puerto colombia
# Processing Record 13 of Set 14 | allanmyo
# City not found. Skipping...
# Processing Record 14 of Set 14 | invermere
# Processing Record 15 of Set 14 | talcahuano
# Processing Record 16 of Set 14 | tessalit
# Processing Record 17 of Set 14 | kuusamo
# Processing Record 18 of Set 14 | zapolyarnyy
# Processing Record 19 of Set 14 | dalvik
# Processing Record 20 of Set 14 | borogontsy
# Processing Record 21 of Set 14 | codrington
# Processing Record 22 of Set 14 | copiapo
# Processing Record 23 of Set 14 | lazaro cardenas
# Processing Record 24 of Set 14 | taylorville
# Processing Record 25 of Set 14 | kapit
# Processing Record 26 of Set 14 | lincoln
# Processing Record 27 of Set 14 | malinovskiy
# Processing Record 28 of Set 14 | juybar
# Processing Record 29 of Set 14 | merauke
# Processing Record 30 of Set 14 | pasighat
# Processing Record 31 of Set 14 | nkhata bay
# Processing Record 32 of Set 14 | birjand
# Processing Record 33 of Set 14 | boa viagem
# Processing Record 34 of Set 14 | erenhot
# Processing Record 35 of Set 14 | verkhnevilyuysk
# Processing Record 36 of Set 14 | ammon
# Processing Record 37 of Set 14 | pangody
# Processing Record 38 of Set 14 | umarkot
# Processing Record 39 of Set 14 | rubiataba
# Processing Record 40 of Set 14 | mentok
# City not found. Skipping...
# Processing Record 41 of Set 14 | mayo
# Processing Record 42 of Set 14 | malatya
# Processing Record 43 of Set 14 | shalinskoye
# Processing Record 44 of Set 14 | ostrovnoy
# Processing Record 45 of Set 14 | mangrol
# Processing Record 46 of Set 14 | hambantota
# Processing Record 47 of Set 14 | djibo
# Processing Record 48 of Set 14 | kandi
# Processing Record 49 of Set 14 | praya
# Processing Record 50 of Set 14 | kurchum
# Processing Record 1 of Set 15 | bijie
# Processing Record 2 of Set 15 | sabirabad
# Processing Record 3 of Set 15 | tumannyy
# City not found. Skipping...
# Processing Record 4 of Set 15 | constitucion
# Processing Record 5 of Set 15 | chicama
# Processing Record 6 of Set 15 | jacareacanga
# Processing Record 7 of Set 15 | iwanai
# Processing Record 8 of Set 15 | kattivakkam
# Processing Record 9 of Set 15 | karpogory
# Processing Record 10 of Set 15 | northam
# Processing Record 11 of Set 15 | ribeira brava
# Processing Record 12 of Set 15 | ranong
# Processing Record 13 of Set 15 | gorontalo
# Processing Record 14 of Set 15 | lakes entrance
# Processing Record 15 of Set 15 | qasigiannguit
# Processing Record 16 of Set 15 | karratha
# Processing Record 17 of Set 15 | atar
# Processing Record 18 of Set 15 | andrushivka
# Processing Record 19 of Set 15 | xuanzhou
# Processing Record 20 of Set 15 | saint-pierre
# Processing Record 21 of Set 15 | acarau
# Processing Record 22 of Set 15 | baker city
# Processing Record 23 of Set 15 | mehriz
# Processing Record 24 of Set 15 | yar-sale
# Processing Record 25 of Set 15 | lluta
# Processing Record 26 of Set 15 | yirol
# City not found. Skipping...
# Processing Record 27 of Set 15 | muroto
# Processing Record 28 of Set 15 | tabou
# Processing Record 29 of Set 15 | bubaque
# Processing Record 30 of Set 15 | mwinilunga
# Processing Record 31 of Set 15 | bistrica
# Processing Record 32 of Set 15 | horasan
# Processing Record 33 of Set 15 | moosburg
# Processing Record 34 of Set 15 | bilma
# Processing Record 35 of Set 15 | heiligenhafen
# Processing Record 36 of Set 15 | geraldton
# Processing Record 37 of Set 15 | tarko-sale
# Processing Record 38 of Set 15 | delijan
# Processing Record 39 of Set 15 | buala
# Processing Record 40 of Set 15 | ambikapur
# Processing Record 41 of Set 15 | dhidhdhoo
# Processing Record 42 of Set 15 | portland
# Processing Record 43 of Set 15 | saint-augustin
# Processing Record 44 of Set 15 | mawlaik
# Processing Record 45 of Set 15 | tateyama
# Processing Record 46 of Set 15 | tamworth
# Processing Record 47 of Set 15 | alappuzha
# Processing Record 48 of Set 15 | aswan
# Processing Record 49 of Set 15 | dodge city
# Processing Record 50 of Set 15 | kautokeino
# Processing Record 1 of Set 16 | thinadhoo
# Processing Record 2 of Set 16 | chapleau
# Processing Record 3 of Set 16 | matagami
# Processing Record 4 of Set 16 | mangaratiba
# Processing Record 5 of Set 16 | mogok
# Processing Record 6 of Set 16 | joshimath
# Processing Record 7 of Set 16 | eyl
# Processing Record 8 of Set 16 | nambucca heads
# Processing Record 9 of Set 16 | beipiao
# Processing Record 10 of Set 16 | san carlos de bariloche
# Processing Record 11 of Set 16 | praia da vitoria
# Processing Record 12 of Set 16 | pyay
# Processing Record 13 of Set 16 | artyom
# Processing Record 14 of Set 16 | burgos
# Processing Record 15 of Set 16 | nchelenge
# Processing Record 16 of Set 16 | maine-soroa
# Processing Record 17 of Set 16 | wollongong
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                    City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0                Amahai  -3.3333  128.9167     83.07        73          41
# 1            Gubkinskiy  64.4340   76.5026     58.37        60          83
# 2             Salisbury  51.0693   -1.7957     60.10        93          77
# 3          Punta Arenas -53.1500  -70.9167     37.51        75           0
# 4               Fortuna  40.5982 -124.1573     55.92        91          90
# 5               Rikitea -23.1203 -134.9692     72.61        79          73
# 6            Chokurdakh  70.6333  147.9167     55.22        55          25
# 7           New Norfolk -42.7826  147.0587     62.92        60          85
# 8              Tasiilaq  65.6145  -37.6368     42.96        78          17
# 9  Sao Jose De Piranhas  -7.1206  -38.5019     69.21        66          41
#
#    Wind Speed Country Current Description
# 0        5.30      ID    scattered clouds
# 1       12.66      RU       broken clouds
# 2        6.49      GB       broken clouds
# 3       23.02      CL           clear sky
# 4        6.91      US     overcast clouds
# 5        8.46      PF       broken clouds
# 6       20.58      RU    scattered clouds
# 7        4.00      AU     overcast clouds
# 8        2.95      GL          few clouds
# 9        9.91      BR    scattered clouds

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Amahai      ID  -3.3333  128.9167     83.07        73          41
# 1      Gubkinskiy      RU  64.4340   76.5026     58.37        60          83
# 2       Salisbury      GB  51.0693   -1.7957     60.10        93          77
# 3    Punta Arenas      CL -53.1500  -70.9167     37.51        75           0
# 4         Fortuna      US  40.5982 -124.1573     55.92        91          90
# ..            ...     ...      ...       ...       ...       ...         ...
# 707        Artyom      AZ  40.4723   50.3330     78.94        68          96
# 708        Burgos      ES  42.3394   -3.7079     52.21       100          90
# 709     Nchelenge      ZM  -9.3451   28.7340     59.34        56           0
# 710   Maine-Soroa      NE  13.2114   12.0241     77.32        75          69
# 711    Wollongong      AU -34.4333  150.8833     72.82        43          35
#
#      Wind Speed Current Description
# 0          5.30    scattered clouds
# 1         12.66       broken clouds
# 2          6.49       broken clouds
# 3         23.02           clear sky
# 4          6.91     overcast clouds
# ..          ...                 ...
# 707        8.77     overcast clouds
# 708       13.80                mist
# 709        7.65           clear sky
# 710        9.17       broken clouds
# 711       13.06    scattered clouds
#
# [712 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the Weather Database into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
